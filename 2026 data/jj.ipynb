# %%
import pandas as pd

data1 = pd.read_csv('Clean data of 2026.csv')
data2 = pd.read_csv('Encoded data.csv')
print('Loaded successful')
# Out:
# Loaded successful

# %%
data2.columns
# Out:
# Index(['year', 'Stage Name', 'Home Team Name', 'rank_home', 'Away Team Name',
#        'rank_away', 'Home Team Score', 'Away Team Score', 'total_goals',
#        'rank_diff', 'points_diff', 'Result', 'total.points_home',
#        'total.points_away', 'favourite', 'original_order', 'points_ratio',
#        'home_top5', 'home_top10', 'home_top20', 'away_top5', 'away_top10',
#        'away_top20', 'last_5score_home', 'last_5conceded_home',
#        'last_5score_away', 'last_5conceded_away', 'Home_attack_strength',
#        'Home_defence_strength', 'Away_attack_strength',
#        'Away_defence_strength', 'is_group', 'is_knockout', 'is_final',
#        'h2h_count', 'h2h_avg_goals', 'h2h_home_win_rate', 'Home Team Encoded',
#        'Away Team Encoded'],
#       dtype='str')

# %%
feat2 = data1.rename(columns={
    'Home team name':'Home Team Name',
    'away team name':'Away Team Name',
    'rank home':'rank_home',
    'last_5matches_goals_home':'last_5score_home',
    'last_5matches_conceded_home':'last_5conceded_home',
    'home_attack_strength':'Home_attack_strength',
    'home_defence_strength':'Home_defence_strength',
    'last_5matches_goals_away':'last_5score_away', 
    'last_5matches_conceded_away':'last_5conceded_away',
    'away_attack_strength':'Away_attack_strength',
    'away_defence_strength':'Away_defence_strength',
    'head to head':'h2h_count',
    'goals_in_head to head meetings':'h2h_avg_goals',
    'home_win_rate_from_h2h':'h2h_home_win_rate',
})
feat2
# Out:
#     year           stage name  Home Team Name  rank_home  Away Team Name  \
# 0   2026  First Stage Group A          Mexico         15    South Africa
# 1   2026  First Stage Group A     South Korea         25  Czech Republic
# 2   2026  First Stage Group A  Czech Republic         41    South Africa
# 3   2026  First Stage Group A          Mexico         15     South Korea
# 4   2026  First Stage Group A  Czech Republic         41          Mexico
# ..   ...                  ...             ...        ...             ...
# 67  2026  First Stage Group L           Ghana         66          Panama
# 68  2026  First Stage Group L         England          4           Ghana
# 69  2026  First Stage Group L          Panama         33         Croatia
# 70  2026  First Stage Group L         Croatia         11           Ghana
# 71  2026  First Stage Group L          Panama         33         England
#
#     rank away  total points home  prevoius points home  total points away  \
# ...

# %%
dataz = feat2.to_csv("Clean Updated data of 2026.csv", index=False)
print('created successful')
#This is to be used in the web page
# Out:
# created successful
